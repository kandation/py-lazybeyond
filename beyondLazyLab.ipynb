# %%
from beyondLean import BeyondLazy, BeyondLazyApi

# %%
b = BeyondLazy('USER', 'PASS')
b.login()
# Out:
# <RequestsCookieJar[<Cookie .AspNet.AccessCookie=A5SX%2fwFzuPn0wlV%2bYL7XFe5dpUcioAs%2bCS5mHbpEXgupIZN3Dcsg%2b4F6RM9yZDfxMR6%2f7%2fTtCBBhO7LfI1lHCA%3d%3d for .vcubelms.com/>, <Cookie ASP.NET_SessionId=aoynrczcvec1makcd2mrmdva for vcubelms.com/>]>

# %%
session = b.get_session()
bx = BeyondLazyApi(session)

# %%
bx.get_task()
# Out:
# {"IsSuccessful":true,"Message":"Pass","Result":{"Status":1,"CurrentCount":5,"UpcomingCount":0,"CompletedCount":4,"ExpiredCount":0,"ClassCount":0,"RegistrationCount":0,"Count":5,"BreakpointContent":null,"Tasks":[{"Num":0,"TaskId":"eee9afcf-6b5d-ec11-819b-00155d00a206","HasCertificate":false,"ResultId":"00000000-0000-0000-0000-000000000000","Name":"หลักสูตร Business model Canvas (BMC)","Type":1,"TypeName":"Course","ClassName":"course","TypeText":"Course (Online)","SupplementType":1,"SupplementInfo":null,"Status":"Current","HasSupplement":false,"AllowStart":true,"IsIntegratedCourse":false,"AuthorName":"Beyondtraining","HasThumbnail":true,"Thumbnail":{"TypeName":"Image","Position":0,"AssetId":"b863f2ef-8279-43dc-aae6-c69e3e1c12fa","FileName":"course-BusinessModelCanvas(BMC).jpg","Type":1,"ContentType":"image/jpeg","Extension":"jpg","ContentLength":244212,"IsVisible":false,"IsAllowDownload":true,"CreatedBy":"8b559251-e857-ec11-8177-00155d01a704","CreatedDate":"2022-01-10T14:12:50","Update
# ...

# %%
bx.take('8e76cd36-a2c3-ed11-9d88-00505601273f')
# Out:
# {"resultId":"8e76cd36-a2c3-ed11-9d88-00505601273f"}
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File D:\Users\kandation\anaconda3\envs\docs\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
# ...
